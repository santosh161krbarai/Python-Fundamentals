# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# question 1
name=input("What is your name? ")
age=int(input("Enter Your age: "))
print(f"Hello {name}, you are {age} years old!")
# Out:
# Hello santohs, you are 23 years old!

# %%
# question 2
num1=int(input("enter first number "))
num2= int(input("Enter second Number "))
sum=num1+num2
difference=num1-num2
product=num2*num1
quotient=num1//num2
remainder=num1%num2
print(f"The sum is {sum}, product is {product}, difference is {difference}, quotient is {quotient} and the remainder is {remainder} ")
# Out:
# The sum is 13, product is 30, difference is 7, quotient is 3 and the remainder is 1

# %%
# question 3
num3=float(input("Enter a float number "))
sum=float(num1)+float(num2)+num3
average=sum/3
print(average)
# Out:
# 5.833333333333333

# %%
#question 4
user_input=input("Enter any input: ")
in_integer=int(user_input)
in_float=float(user_input)
print(user_input,type(user_input))
print(in_integer,type(in_integer))
print(in_float,type(in_float))
# Out:
# 123 <class 'str'>
# 123 <class 'int'>
# 123.0 <class 'float'>

# %%
# question 5
x=10+3*2**2 #22
print(x)
 
 # The output flow the precendence rule of operator
 # The power evaluates first then multiply and then addition
# Out:
# 22

# %%
# question 6
a=int(input("Num1: "))
b=int(input("Num2: "))
# a,b=b,a #swap
# print("a=",a, "b=", b)
c=a
a=b     #Using 3rd variable
b=c
print(a,b)
# Out:
# 5 4

# %%
#question 7
celsius=input("Enter temperature in celsius ")
float_celsius=float(celsius)
fahrenheit= (float_celsius*(9/5))+32
print("The temperature in fahrenheit is", fahrenheit)
# Out:
# The temperature in fahrenheit is 98.60000000000001

# %%
# question 8
radius=int(input("Enter the radius: "))
PI=3.14
area=PI*radius**2
print(area)
# Out:
# 50.24

# %%
# question 9
values=list(map(int, input("Enter P,R,T:").split(" ")))
print(values)
SI=(values[0]*values[1]*values[2])/100
print(SI)
# Out:
# [1200, 10, 5]
# 600.0

# %%
# question 10
number=float(input("Enter a float number: "))
int_part=int(number)
# frac_part=round(number-int_part,2) #round to 2 decimal places
frac_part=number-int_part
print(f"The integer part is {int_part} and the fractional part is {frac_part:.2f}")
# Out:
# The integer part is 45 and the fractional part is 0.68
